# %%
import torch 
import torch.nn as nn
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.1 MB 14.7 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.1 MB 12.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 11.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 14.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    -------------- ------------------------- 4.5/12.3 MB 22.4 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.3 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 20.8 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_and_plot(model, loader, device, classes):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = outputs.argmax(1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # 1. Classification Report (Precision, Recall, F1)
    # Research tip: Report the 'Macro Average' for balanced view across all 58 classes
    print("\n--- Research Classification Report ---")
    print(classification_report(all_labels, all_preds, target_names=classes))

# Fix: Re-initialize test_loader with appropriate transforms for evaluation
# Define the test transform if not already globally available
test_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

# Create a new test_dataset with the transform
test_ds_eval = datasets.ImageFolder(test_dir, transform=test_transform)

# Create a new test_loader for evaluation, using a batch size suitable for metrics calculation
test_loader_eval = DataLoader(test_ds_eval, batch_size=BATCH_SIZE, shuffle=False)
evaluate_and_plot(model, test_loader_eval, device, class_names)
